# %%
sk-mVwwKRHJx31ouQHziC3CT3BlbkFJP8Yv1gB2L7ebWToz6L9Jj

# %%
# !pip install griptape[all] -U
# Out:
# Collecting griptape[all]
#   Obtaining dependency information for griptape[all] from https://files.pythonhosted.org/packages/cb/a5/601530ed2d8b5dc8e3a77d1ab19bb094c3c3fec7ed9881601a9f0dfd9542/griptape-0.23.0-py3-none-any.whl.metadata
#   Downloading griptape-0.23.0-py3-none-any.whl.metadata (15 kB)
# Collecting anthropic<0.8.0,>=0.7.8 (from griptape[all])
#   Obtaining dependency information for anthropic<0.8.0,>=0.7.8 from https://files.pythonhosted.org/packages/0d/ba/fdbc205b584950991fe20cf61b6eb8d6fe52dabc1c231e0d509c6f25de38/anthropic-0.7.8-py3-none-any.whl.metadata
#   Downloading anthropic-0.7.8-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: attrs>=22 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from griptape[all]) (23.2.0)
# Collecting boto3<2.0.0,>=1.28.2 (from griptape[all])
#   Obtaining dependency information for boto3<2.0.0,>=1.28.2 from https://files.pythonhosted.org/packages/00/a7/b950d33d63fb80d6dbe8295641560f4697444ce89ff117e2ecaf78e95044/boto3-1.34.54-py3-none-any.whl.metadata
#   Downloading boto3-1.34.54-py3-none-any.whl.metadata (6.6 kB)
# Collecting boto3-stubs[bedrock,iam,opensearch,s3,sagemaker]<2.0.0,>=1.34.18 (from griptape[all])
#   Obtaining dependency information for boto3-stubs[bedrock,iam,opensearch,s3,sagemaker]<2.0.0,>=1.34.18 from https://files.pythonhosted.org/packages/9a/e4/ea4d58b6283b0682b7ebd3ce5857dd78f2e2afb030ace0cd78c7ab73dc7b/boto3_stubs-1.34.54-py3-none-any.whl.metadata
#   Downloading boto3_stubs-1.34.54-py3-none-any.whl.metadata (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.2/140.2 kB 827.4 kB/s eta 0:00:00 kB/s eta 0:00:01
# Collecting cohere>=4 (from griptape[all])
#   Obtaining dependency information for cohere>=4 from https://files.pythonhosted.org/packages/ee/40/8506b471ee0e0a565ecc6d6933591c4a91164c67ef1de9d55d66de613754/cohere-4.51-py3-none-any.whl.metadata
#   Downloading cohere-4.51-py3-none-any.whl.metadata (6.0 kB)
# Collecting dateparser<2.0.0,>=1.1.8 (from griptape[all])
#   Obtaining dependency information for dateparser<2.0.0,>=1.1.8 from https://files.pythonhosted.org/packages/a4/29/db12aa4dda81580be1999824a689bd52aa40061fc12c9ccdc3feab5ea718/dateparser-1.2.0-py2.py3-none-any.whl.metadata
#   Downloading dateparser-1.2.0-py2.py3-none-any.whl.metadata (28 kB)
# Collecting docker<7.0.0,>=6.1.3 (from griptape[all])
#   Obtaining dependency information for docker<7.0.0,>=6.1.3 from https://files.pythonhosted.org/packages/db/be/3032490fa33b36ddc8c4b1da3252c6f974e7133f1a50de00c6b85cca203a/docker-6.1.3-py3-none-any.whl.metadata
#   Downloading docker-6.1.3-py3-none-any.whl.metadata (3.5 kB)
# Collecting jinja2>=3.1.3 (from griptape[all])
#   Obtaining dependency information for jinja2>=3.1.3 from https://files.pythonhosted.org/packages/30/6d/6de6be2d02603ab56e72997708809e8a5b0fbfee080735109b40a3564843/Jinja2-3.1.3-py3-none-any.whl.metadata
#   Downloading Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: jsonschema>=4 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from griptape[all]) (4.21.1)
# Collecting mail-parser<4.0.0,>=3.15.0 (from griptape[all])
#   Obtaining dependency information for mail-parser<4.0.0,>=3.15.0 from https://files.pythonhosted.org/packages/67/5a/6ad8c80b10fe92a6d123660b63fa3e23a7a0fe55c20201ab794c9d714f0e/mail_parser-3.15.0-py3-none-any.whl.metadata
#   Downloading mail_parser-3.15.0-py3-none-any.whl.metadata (9.9 kB)
# Collecting marqo>=1.1.0 (from griptape[all])
#   Obtaining dependency information for marqo>=1.1.0 from https://files.pythonhosted.org/packages/16/d1/7c44e6ed2e1abca29b2a9c7e454ab26d9ee9e0576b772e233d95a6174c02/marqo-3.1.0-py3-none-any.whl.metadata
#   Downloading marqo-3.1.0-py3-none-any.whl.metadata (22 kB)
# Collecting marshmallow>=3 (from griptape[all])
#   Obtaining dependency information for marshmallow>=3 from https://files.pythonhosted.org/packages/f5/97/6e4ddd6713bba5ede1d18f3959d7bffde38e56f7f7ae7c031c9a3d746b95/marshmallow-3.21.0-py3-none-any.whl.metadata
#   Downloading marshmallow-3.21.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting marshmallow-enum>=1.5 (from griptape[all])
#   Obtaining dependency information for marshmallow-enum>=1.5 from https://files.pythonhosted.org/packages/c6/59/ef3a3dc499be447098d4a89399beb869f813fee1b5a57d5d79dee2c1bf51/marshmallow_enum-1.5.1-py2.py3-none-any.whl.metadata
#   Downloading marshmallow_enum-1.5.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy>=1 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from griptape[all]) (1.24.3)
# Requirement already satisfied: openai<2.0.0,>=1.1.1 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from griptape[all]) (1.13.3)
# Collecting opensearch-py<3.0.0,>=2.3.1 (from griptape[all])
#   Obtaining dependency information for opensearch-py<3.0.0,>=2.3.1 from https://files.pythonhosted.org/packages/6a/88/8f48281e1f8d48746ab7061a7c2ab37b4a57b358f04159cd9daa3dafe04b/opensearch_py-2.4.2-py2.py3-none-any.whl.metadata
#   Downloading opensearch_py-2.4.2-py2.py3-none-any.whl.metadata (6.8 kB)
# Collecting pandas<2.0,>=1.3 (from griptape[all])
#   Obtaining dependency information for pandas<2.0,>=1.3 from https://files.pythonhosted.org/packages/56/73/3351beeb807dca69fcc3c4966bcccc51552bd01549a9b13c04ab00a43f21/pandas-1.5.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading pandas-1.5.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting pgvector<0.3.0,>=0.2.3 (from griptape[all])
#   Obtaining dependency information for pgvector<0.3.0,>=0.2.3 from https://files.pythonhosted.org/packages/29/bb/4686b1090a7c68fa367e981130a074dc6c1236571d914ffa6e05c882b59d/pgvector-0.2.5-py2.py3-none-any.whl.metadata
#   Downloading pgvector-0.2.5-py2.py3-none-any.whl.metadata (9.9 kB)
# Collecting pillow<11.0.0,>=10.2.0 (from griptape[all])
#   Obtaining dependency information for pillow<11.0.0,>=10.2.0 from https://files.pythonhosted.org/packages/66/9c/2e1877630eb298bbfd23f90deeec0a3f682a4163d5ca9f178937de57346c/pillow-10.2.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata
#   Downloading pillow-10.2.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Collecting pinecone-client<3,>=2 (from griptape[all])
#   Obtaining dependency information for pinecone-client<3,>=2 from https://files.pythonhosted.org/packages/df/d4/cffbb61236c6c1d7510e835c1ff843e4e7d705ed59d21c0e5b6dc1cb4fd8/pinecone_client-2.2.4-py3-none-any.whl.metadata
#   Downloading pinecone_client-2.2.4-py3-none-any.whl.metadata (7.8 kB)
# Collecting psycopg2-binary<3.0.0,>=2.9.9 (from griptape[all])
#   Obtaining dependency information for psycopg2-binary<3.0.0,>=2.9.9 from https://files.pythonhosted.org/packages/ce/85/62825cabc6aad53104b7b6d12eb2ad74737d268630032d07b74d4444cb72/psycopg2_binary-2.9.9-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading psycopg2_binary-2.9.9-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Collecting pymongo (from griptape[all])
#   Obtaining dependency information for pymongo from https://files.pythonhosted.org/packages/75/29/b86329e8333ecc93e105e2ee89941ab8be002087a491ab5c26289925bc53/pymongo-4.6.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading pymongo-4.6.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting pypdf<4.0,>=3.9 (from griptape[all])
#   Obtaining dependency information for pypdf<4.0,>=3.9 from https://files.pythonhosted.org/packages/29/10/055b649e914ad8c5d07113c22805014988825abbeff007b0e89255b481fa/pypdf-3.17.4-py3-none-any.whl.metadata
#   Downloading pypdf-3.17.4-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: pyyaml>=6 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from griptape[all]) (6.0)
# Collecting redis<5.0.0,>=4.6.0 (from griptape[all])
#   Obtaining dependency information for redis<5.0.0,>=4.6.0 from https://files.pythonhosted.org/packages/20/2e/409703d645363352a20c944f5d119bdae3eb3034051a53724a7c5fee12b8/redis-4.6.0-py3-none-any.whl.metadata
#   Downloading redis-4.6.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: requests<3,>=2 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from griptape[all]) (2.31.0)
# Collecting rich>=13 (from griptape[all])
#   Obtaining dependency information for rich>=13 from https://files.pythonhosted.org/packages/87/67/a37f6214d0e9fe57f6ae54b2956d550ca8365857f42a1ce0392bb21d9410/rich-13.7.1-py3-none-any.whl.metadata
#   Downloading rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting schema>=0.7 (from griptape[all])
#   Obtaining dependency information for schema>=0.7 from https://files.pythonhosted.org/packages/0d/93/ca8aa5a772efd69043d0a745172d92bee027caa7565c7f774a2f44b91207/schema-0.7.5-py2.py3-none-any.whl.metadata
#   Downloading schema-0.7.5-py2.py3-none-any.whl.metadata (34 kB)
# Collecting snowflake-sqlalchemy<2.0.0,>=1.4.7 (from griptape[all])
#   Obtaining dependency information for snowflake-sqlalchemy<2.0.0,>=1.4.7 from https://files.pythonhosted.org/packages/c7/fb/649e1847884019aa7a73ef8436150b14f00baedac13eb4bb6658492682da/snowflake_sqlalchemy-1.5.1-py2.py3-none-any.whl.metadata
#   Downloading snowflake_sqlalchemy-1.5.1-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: sqlalchemy<2.0,>=1.0 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from griptape[all]) (1.4.39)
# Collecting sqlalchemy-redshift (from griptape[all])
#   Obtaining dependency information for sqlalchemy-redshift from https://files.pythonhosted.org/packages/17/8b/2c7201607a9a5d997ace6ca907d1dea9271fd399560b082d3432a72046af/sqlalchemy_redshift-0.8.14-py2.py3-none-any.whl.metadata
#   Downloading sqlalchemy_redshift-0.8.14-py2.py3-none-any.whl.metadata (18 kB)
# Collecting stringcase<2.0.0,>=1.2.0 (from griptape[all])
#   Using cached stringcase-1.2.0.tar.gz (3.0 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tenacity>=8.0 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from griptape[all]) (8.2.2)
# Requirement already satisfied: tiktoken>=0.3 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from griptape[all]) (0.6.0)
# Collecting trafilatura<2.0,>=1.6 (from griptape[all])
#   Obtaining dependency information for trafilatura<2.0,>=1.6 from https://files.pythonhosted.org/packages/14/13/fb2e36f1004c462a37b46c21092c2ccbc3e9c2311f493cf5373df82f9e67/trafilatura-1.7.0-py3-none-any.whl.metadata
#   Downloading trafilatura-1.7.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: transformers<5.0,>=4.30 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from griptape[all]) (4.32.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from anthropic<0.8.0,>=0.7.8->griptape[all]) (3.5.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from anthropic<0.8.0,>=0.7.8->griptape[all]) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from anthropic<0.8.0,>=0.7.8->griptape[all]) (0.26.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from anthropic<0.8.0,>=0.7.8->griptape[all]) (1.10.8)
# Requirement already satisfied: sniffio in /home/amodraper/anaconda3/lib/python3.11/site-packages (from anthropic<0.8.0,>=0.7.8->griptape[all]) (1.2.0)
# Requirement already satisfied: tokenizers>=0.13.0 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from anthropic<0.8.0,>=0.7.8->griptape[all]) (0.13.2)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from anthropic<0.8.0,>=0.7.8->griptape[all]) (4.7.1)
# Collecting botocore<1.35.0,>=1.34.54 (from boto3<2.0.0,>=1.28.2->griptape[all])
#   Obtaining dependency information for botocore<1.35.0,>=1.34.54 from https://files.pythonhosted.org/packages/58/ec/9f382db663962e0ba84e706112a984287e3952c2d129aca1d86575bca202/botocore-1.34.54-py3-none-any.whl.metadata
#   Downloading botocore-1.34.54-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from boto3<2.0.0,>=1.28.2->griptape[all]) (0.10.0)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3<2.0.0,>=1.28.2->griptape[all])
#   Obtaining dependency information for s3transfer<0.11.0,>=0.10.0 from https://files.pythonhosted.org/packages/12/bb/7e7912e18cd558e7880d9b58ffc57300b2c28ffba9882b3a54ba5ce3ebc4/s3transfer-0.10.0-py3-none-any.whl.metadata
#   Downloading s3transfer-0.10.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting botocore-stubs (from boto3-stubs[bedrock,iam,opensearch,s3,sagemaker]<2.0.0,>=1.34.18->griptape[all])
#   Obtaining dependency information for botocore-stubs from https://files.pythonhosted.org/packages/d0/30/ca59af5458d8660ba6bba53bb7a78752ac5139a02a721fa4b09c84baa453/botocore_stubs-1.34.54-py3-none-any.whl.metadata
#   Downloading botocore_stubs-1.34.54-py3-none-any.whl.metadata (3.4 kB)
# Collecting types-s3transfer (from boto3-stubs[bedrock,iam,opensearch,s3,sagemaker]<2.0.0,>=1.34.18->griptape[all])
#   Obtaining dependency information for types-s3transfer from https://files.pythonhosted.org/packages/58/bb/53514ca17e5585360f8ea94bae9e75611c114ca8df701b10f5c713e38a9c/types_s3transfer-0.10.0-py3-none-any.whl.metadata
#   Downloading types_s3transfer-0.10.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting mypy-boto3-bedrock<1.35.0,>=1.34.0 (from boto3-stubs[bedrock,iam,opensearch,s3,sagemaker]<2.0.0,>=1.34.18->griptape[all])
#   Obtaining dependency information for mypy-boto3-bedrock<1.35.0,>=1.34.0 from https://files.pythonhosted.org/packages/51/07/4672745e51e3bcc530de9aee1e56da53ba700d8f0aaabce4342ffb0c3e60/mypy_boto3_bedrock-1.34.0-py3-none-any.whl.metadata
#   Downloading mypy_boto3_bedrock-1.34.0-py3-none-any.whl.metadata (13 kB)
# Collecting mypy-boto3-iam<1.35.0,>=1.34.0 (from boto3-stubs[bedrock,iam,opensearch,s3,sagemaker]<2.0.0,>=1.34.18->griptape[all])
#   Obtaining dependency information for mypy-boto3-iam<1.35.0,>=1.34.0 from https://files.pythonhosted.org/packages/3c/e6/6af18bef4af290ce80678ccc3775594a4ed49169e1cefdb458a289b7fb49/mypy_boto3_iam-1.34.8-py3-none-any.whl.metadata
#   Downloading mypy_boto3_iam-1.34.8-py3-none-any.whl.metadata (22 kB)
# Collecting mypy-boto3-opensearch<1.35.0,>=1.34.0 (from boto3-stubs[bedrock,iam,opensearch,s3,sagemaker]<2.0.0,>=1.34.18->griptape[all])
#   Obtaining dependency information for mypy-boto3-opensearch<1.35.0,>=1.34.0 from https://files.pythonhosted.org/packages/82/62/1aefa62355c3ff3311a1a68ec659d992838e0ede67b66c50c41a4ab857d5/mypy_boto3_opensearch-1.34.43-py3-none-any.whl.metadata
#   Downloading mypy_boto3_opensearch-1.34.43-py3-none-any.whl.metadata (12 kB)
# Collecting mypy-boto3-s3<1.35.0,>=1.34.0 (from boto3-stubs[bedrock,iam,opensearch,s3,sagemaker]<2.0.0,>=1.34.18->griptape[all])
#   Obtaining dependency information for mypy-boto3-s3<1.35.0,>=1.34.0 from https://files.pythonhosted.org/packages/64/4a/f1651a6e1ee48eb2a41ede02a442600051953b7a850192d938c95a247004/mypy_boto3_s3-1.34.14-py3-none-any.whl.metadata
#   Downloading mypy_boto3_s3-1.34.14-py3-none-any.whl.metadata (17 kB)
# Collecting mypy-boto3-sagemaker<1.35.0,>=1.34.0 (from boto3-stubs[bedrock,iam,opensearch,s3,sagemaker]<2.0.0,>=1.34.18->griptape[all])
#   Obtaining dependency information for mypy-boto3-sagemaker<1.35.0,>=1.34.0 from https://files.pythonhosted.org/packages/10/38/7b9157bae06965bf4bc2fc1663cdd8860fa76e320dc6ca666617831135f2/mypy_boto3_sagemaker-1.34.53-py3-none-any.whl.metadata
#   Downloading mypy_boto3_sagemaker-1.34.53-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: aiohttp<4.0,>=3.0 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from cohere>=4->griptape[all]) (3.8.5)
# Collecting backoff<3.0,>=2.0 (from cohere>=4->griptape[all])
#   Obtaining dependency information for backoff<3.0,>=2.0 from https://files.pythonhosted.org/packages/df/73/b6e24bd22e6720ca8ee9a85a0c4a2971af8497d8f3193fa05390cbd46e09/backoff-2.2.1-py3-none-any.whl.metadata
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting fastavro<2.0,>=1.8 (from cohere>=4->griptape[all])
#   Obtaining dependency information for fastavro<2.0,>=1.8 from https://files.pythonhosted.org/packages/bb/f1/0b2f1ef950e948f8eab7bcf6fcbbccdfcd5468cf269c1133b3bd02648a1f/fastavro-1.9.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading fastavro-1.9.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: importlib_metadata<7.0,>=6.0 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from cohere>=4->griptape[all]) (6.0.0)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from cohere>=4->griptape[all]) (1.26.16)
# Requirement already satisfied: python-dateutil in /home/amodraper/anaconda3/lib/python3.11/site-packages (from dateparser<2.0.0,>=1.1.8->griptape[all]) (2.8.2)
# Requirement already satisfied: pytz in /home/amodraper/anaconda3/lib/python3.11/site-packages (from dateparser<2.0.0,>=1.1.8->griptape[all]) (2023.3.post1)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from dateparser<2.0.0,>=1.1.8->griptape[all]) (2022.7.9)
# Collecting tzlocal (from dateparser<2.0.0,>=1.1.8->griptape[all])
#   Obtaining dependency information for tzlocal from https://files.pythonhosted.org/packages/97/3f/c4c51c55ff8487f2e6d0e618dba917e3c3ee2caae6cf0fbb59c9b1876f2e/tzlocal-5.2-py3-none-any.whl.metadata
#   Downloading tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: packaging>=14.0 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from docker<7.0.0,>=6.1.3->griptape[all]) (23.2)
# Requirement already satisfied: websocket-client>=0.32.0 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from docker<7.0.0,>=6.1.3->griptape[all]) (0.58.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from jinja2>=3.1.3->griptape[all]) (2.1.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from jsonschema>=4->griptape[all]) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from jsonschema>=4->griptape[all]) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from jsonschema>=4->griptape[all]) (0.17.1)
# Collecting simplejson>=3.17.0 (from mail-parser<4.0.0,>=3.15.0->griptape[all])
#   Obtaining dependency information for simplejson>=3.17.0 from https://files.pythonhosted.org/packages/70/c1/816573ae91aebf06a0fefd8ea30ca43127aa58e68684d2ddfe17c8457afb/simplejson-3.19.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading simplejson-3.19.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.1 kB)
# Requirement already satisfied: six>=1.14.0 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from mail-parser<4.0.0,>=3.15.0->griptape[all]) (1.16.0)
# Requirement already satisfied: tqdm>4 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from openai<2.0.0,>=1.1.1->griptape[all]) (4.65.0)
# Collecting urllib3<3,>=1.26 (from cohere>=4->griptape[all])
#   Obtaining dependency information for urllib3<3,>=1.26 from https://files.pythonhosted.org/packages/b0/53/aa91e163dcfd1e5b82d8a890ecf13314e3e149c05270cc644581f77f17fd/urllib3-1.26.18-py2.py3-none-any.whl.metadata
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2022.12.07 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from opensearch-py<3.0.0,>=2.3.1->griptape[all]) (2023.7.22)
# Collecting loguru>=0.5.0 (from pinecone-client<3,>=2->griptape[all])
#   Obtaining dependency information for loguru>=0.5.0 from https://files.pythonhosted.org/packages/03/0a/4f6fed21aa246c6b49b561ca55facacc2a44b87d65b8b92362a8e99ba202/loguru-0.7.2-py3-none-any.whl.metadata
#   Downloading loguru-0.7.2-py3-none-any.whl.metadata (23 kB)
# Collecting dnspython>=2.0.0 (from pinecone-client<3,>=2->griptape[all])
#   Obtaining dependency information for dnspython>=2.0.0 from https://files.pythonhosted.org/packages/87/a1/8c5287991ddb8d3e4662f71356d9656d91ab3a36618c3dd11b280df0d255/dnspython-2.6.1-py3-none-any.whl.metadata
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from requests<3,>=2->griptape[all]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from requests<3,>=2->griptape[all]) (3.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from rich>=13->griptape[all]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from rich>=13->griptape[all]) (2.15.1)
# Collecting contextlib2>=0.5.5 (from schema>=0.7->griptape[all])
#   Obtaining dependency information for contextlib2>=0.5.5 from https://files.pythonhosted.org/packages/76/56/6d6872f79d14c0cb02f1646cbb4592eef935857c0951a105874b7b62a0c3/contextlib2-21.6.0-py2.py3-none-any.whl.metadata
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting snowflake-connector-python<4.0.0 (from snowflake-sqlalchemy<2.0.0,>=1.4.7->griptape[all])
#   Obtaining dependency information for snowflake-connector-python<4.0.0 from https://files.pythonhosted.org/packages/6b/67/5f4d1ea490d8b266397dd45de1cc320a3dd41fb4359bae6c52d7707e16bb/snowflake_connector_python-3.7.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading snowflake_connector_python-3.7.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: greenlet!=0.4.17 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from sqlalchemy<2.0,>=1.0->griptape[all]) (2.0.1)
# Collecting courlan>=0.9.5 (from trafilatura<2.0,>=1.6->griptape[all])
#   Obtaining dependency information for courlan>=0.9.5 from https://files.pythonhosted.org/packages/2a/89/3d613919e1848640870d2b4ed474e0d8f96b0d2897dea13c44fc8aed8755/courlan-1.0.0-py3-none-any.whl.metadata
#   Downloading courlan-1.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting htmldate>=1.7.0 (from trafilatura<2.0,>=1.6->griptape[all])
#   Obtaining dependency information for htmldate>=1.7.0 from https://files.pythonhosted.org/packages/06/c4/59f980effd5c3217b1a83f4098cd3383e8d17a1976be1f4157364055c3fa/htmldate-1.7.0-py3-none-any.whl.metadata
#   Downloading htmldate-1.7.0-py3-none-any.whl.metadata (11 kB)
# Collecting justext>=3.0.0 (from trafilatura<2.0,>=1.6->griptape[all])
#   Obtaining dependency information for justext>=3.0.0 from https://files.pythonhosted.org/packages/36/b1/1b2314a6d3116c723696ff1ea16e5e6185ee9bdf4dbfcd06bbfee04e65e1/jusText-3.0.0-py2.py3-none-any.whl.metadata
#   Downloading jusText-3.0.0-py2.py3-none-any.whl.metadata (6.8 kB)
# Collecting lxml<6,>=4.9.4 (from trafilatura<2.0,>=1.6->griptape[all])
#   Obtaining dependency information for lxml<6,>=4.9.4 from https://files.pythonhosted.org/packages/1f/09/df0101e6d7be06fca545c0f7417d03d69679ff280d892a406469086780a4/lxml-5.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading lxml-5.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.5 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2->griptape[all])
#   Obtaining dependency information for charset-normalizer<4,>=2 from https://files.pythonhosted.org/packages/40/26/f35951c45070edc957ba40a5b1db3cf60a9dbb1b350c2d5bef03e01e61de/charset_normalizer-3.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading charset_normalizer-3.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Requirement already satisfied: filelock in /home/amodraper/anaconda3/lib/python3.11/site-packages (from transformers<5.0,>=4.30->griptape[all]) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from transformers<5.0,>=4.30->griptape[all]) (0.15.1)
# Requirement already satisfied: safetensors>=0.3.1 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from transformers<5.0,>=4.30->griptape[all]) (0.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0,>=3.0->cohere>=4->griptape[all]) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0,>=3.0->cohere>=4->griptape[all]) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0,>=3.0->cohere>=4->griptape[all]) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0,>=3.0->cohere>=4->griptape[all]) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0,>=3.0->cohere>=4->griptape[all]) (1.2.0)
# Collecting langcodes>=3.3.0 (from courlan>=0.9.5->trafilatura<2.0,>=1.6->griptape[all])
#   Obtaining dependency information for langcodes>=3.3.0 from https://files.pythonhosted.org/packages/fe/c3/0d04d248624a181e57c2870127dfa8d371973561caf54333c85e8f9133a2/langcodes-3.3.0-py3-none-any.whl.metadata
#   Downloading langcodes-3.3.0-py3-none-any.whl.metadata (29 kB)
# Collecting tld>=0.13 (from courlan>=0.9.5->trafilatura<2.0,>=1.6->griptape[all])
#   Obtaining dependency information for tld>=0.13 from https://files.pythonhosted.org/packages/ea/75/779ddeaf4d847ba0021ad99d1b615a853f2a5762bd5d118273c7f7673c38/tld-0.13-py2.py3-none-any.whl.metadata
#   Downloading tld-0.13-py2.py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: httpcore==1.* in /home/amodraper/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->anthropic<0.8.0,>=0.7.8->griptape[all]) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->anthropic<0.8.0,>=0.7.8->griptape[all]) (0.14.0)
# Requirement already satisfied: fsspec in /home/amodraper/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers<5.0,>=4.30->griptape[all]) (2023.4.0)
# Requirement already satisfied: zipp>=0.5 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from importlib_metadata<7.0,>=6.0->cohere>=4->griptape[all]) (3.11.0)
# Requirement already satisfied: mdurl~=0.1 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13->griptape[all]) (0.1.0)
# Collecting asn1crypto<2.0.0,>0.24.0 (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy<2.0.0,>=1.4.7->griptape[all])
#   Obtaining dependency information for asn1crypto<2.0.0,>0.24.0 from https://files.pythonhosted.org/packages/c9/7f/09065fd9e27da0eda08b4d6897f1c13535066174cc023af248fc2a8d5e5a/asn1crypto-1.5.1-py2.py3-none-any.whl.metadata
#   Downloading asn1crypto-1.5.1-py2.py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy<2.0.0,>=1.4.7->griptape[all]) (1.15.1)
# Requirement already satisfied: cryptography<43.0.0,>=3.1.0 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy<2.0.0,>=1.4.7->griptape[all]) (41.0.3)
# Requirement already satisfied: pyOpenSSL<25.0.0,>=16.2.0 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy<2.0.0,>=1.4.7->griptape[all]) (23.2.0)
# Requirement already satisfied: pyjwt<3.0.0 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy<2.0.0,>=1.4.7->griptape[all]) (2.4.0)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy<2.0.0,>=1.4.7->griptape[all]) (2.4.0)
# Requirement already satisfied: platformdirs<4.0.0,>=2.6.0 in /home/amodraper/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy<2.0.0,>=1.4.7->griptape[all]) (3.10.0)
# Requirement already satisfied: tomlkit in /home/amodraper/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy<2.0.0,>=1.4.7->griptape[all]) (0.11.1)
# Collecting types-awscrt (from botocore-stubs->boto3-stubs[bedrock,iam,opensearch,s3,sagemaker]<2.0.0,>=1.34.18->griptape[all])
#   Obtaining dependency information for types-awscrt from https://files.pythonhosted.org/packages/0c/60/57af8a2f05ab05a0218030ff2f96cfbc232055f0d2a0b5320d59187c4e82/types_awscrt-0.20.5-py3-none-any.whl.metadata
#   Downloading types_awscrt-0.20.5-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: pycparser in /home/amodraper/anaconda3/lib/python3.11/site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python<4.0.0->snowflake-sqlalchemy<2.0.0,>=1.4.7->griptape[all]) (2.21)
# Using cached anthropic-0.7.8-py3-none-any.whl (807 kB)
# Using cached boto3-1.34.54-py3-none-any.whl (139 kB)
# Using cached cohere-4.51-py3-none-any.whl (52 kB)
# Using cached dateparser-1.2.0-py2.py3-none-any.whl (294 kB)
# Using cached docker-6.1.3-py3-none-any.whl (148 kB)
# Using cached Jinja2-3.1.3-py3-none-any.whl (133 kB)
# Using cached mail_parser-3.15.0-py3-none-any.whl (25 kB)
# Using cached marqo-3.1.0-py3-none-any.whl (37 kB)
# Using cached marshmallow-3.21.0-py3-none-any.whl (49 kB)
# Using cached marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Using cached opensearch_py-2.4.2-py2.py3-none-any.whl (258 kB)
# Downloading pandas-1.5.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 8.1 MB/s eta 0:00:00m eta 0:00:010:01:01
# Using cached pgvector-0.2.5-py2.py3-none-any.whl (9.6 kB)
# Downloading pillow-10.2.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 10.7 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Using cached pinecone_client-2.2.4-py3-none-any.whl (179 kB)
# Downloading psycopg2_binary-2.9.9-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 13.1 MB/s eta 0:00:0031m14.0 MB/s eta 0:00:01
# Using cached pypdf-3.17.4-py3-none-any.whl (278 kB)
# Using cached redis-4.6.0-py3-none-any.whl (241 kB)
# Using cached rich-13.7.1-py3-none-any.whl (240 kB)
# Using cached schema-0.7.5-py2.py3-none-any.whl (17 kB)
# Using cached snowflake_sqlalchemy-1.5.1-py2.py3-none-any.whl (39 kB)
# Using cached trafilatura-1.7.0-py3-none-any.whl (1.0 MB)
# Using cached griptape-0.23.0-py3-none-any.whl (249 kB)
# Downloading pymongo-4.6.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (680 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 680.9/680.9 kB 6.7 MB/s eta 0:00:00 MB/s eta 0:00:01
# Using cached sqlalchemy_redshift-0.8.14-py2.py3-none-any.whl (38 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached botocore-1.34.54-py3-none-any.whl (12.0 MB)
# Downloading charset_normalizer-3.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.3/140.3 kB 10.1 MB/s eta 0:00:00
# Using cached contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Using cached courlan-1.0.0-py3-none-any.whl (35 kB)
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 16.0 MB/s eta 0:00:00
# Downloading fastavro-1.9.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 15.6 MB/s eta 0:00:00m eta 0:00:010:01:01
# Using cached htmldate-1.7.0-py3-none-any.whl (40 kB)
# Using cached jusText-3.0.0-py2.py3-none-any.whl (837 kB)
# Using cached loguru-0.7.2-py3-none-any.whl (62 kB)
# Downloading lxml-5.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 9.9 MB/s eta 0:00:000m eta 0:00:010:01:01
# Using cached mypy_boto3_bedrock-1.34.0-py3-none-any.whl (27 kB)
# Using cached mypy_boto3_iam-1.34.8-py3-none-any.whl (87 kB)
# Using cached mypy_boto3_opensearch-1.34.43-py3-none-any.whl (44 kB)
# Using cached mypy_boto3_s3-1.34.14-py3-none-any.whl (82 kB)
# Using cached mypy_boto3_sagemaker-1.34.53-py3-none-any.whl (211 kB)
# Using cached s3transfer-0.10.0-py3-none-any.whl (82 kB)
# Downloading simplejson-3.19.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.7/144.7 kB 24.6 MB/s eta 0:00:00
# Downloading snowflake_connector_python-3.7.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 16.3 MB/s eta 0:00:000:00:010:00:01:01
# Using cached urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
# Using cached boto3_stubs-1.34.54-py3-none-any.whl (56 kB)
# Using cached botocore_stubs-1.34.54-py3-none-any.whl (59 kB)
# Using cached types_s3transfer-0.10.0-py3-none-any.whl (17 kB)
# Using cached tzlocal-5.2-py3-none-any.whl (17 kB)
# Using cached asn1crypto-1.5.1-py2.py3-none-any.whl (105 kB)
# Using cached langcodes-3.3.0-py3-none-any.whl (181 kB)
# Using cached tld-0.13-py2.py3-none-any.whl (263 kB)
# Using cached types_awscrt-0.20.5-py3-none-any.whl (17 kB)
# Building wheels for collected packages: stringcase
#   Building wheel for stringcase (setup.py) ... done
#   Created wheel for stringcase: filename=stringcase-1.2.0-py3-none-any.whl size=3569 sha256=cd4180420abf9ab693b6d19c3db934bc455a980ead8eefc7b7705be01ad26e4b
#   Stored in directory: /home/amodraper/.cache/pip/wheels/b4/33/6d/d0820be98063da218c3206fbad2381cd2db3fbb1a0f0d254b5
# Successfully built stringcase
# Installing collected packages: stringcase, asn1crypto, urllib3, tzlocal, types-s3transfer, types-awscrt, tld, simplejson, redis, pypdf, psycopg2-binary, pillow, pgvector, mypy-boto3-sagemaker, mypy-boto3-s3, mypy-boto3-opensearch, mypy-boto3-iam, mypy-boto3-bedrock, marshmallow, lxml, loguru, langcodes, jinja2, fastavro, dnspython, contextlib2, charset-normalizer, backoff, sqlalchemy-redshift, schema, rich, pymongo, pandas, marshmallow-enum, mail-parser, justext, dateparser, courlan, botocore-stubs, botocore, s3transfer, pinecone-client, opensearch-py, marqo, htmldate, docker, cohere, boto3-stubs, anthropic, trafilatura, snowflake-connector-python, boto3, snowflake-sqlalchemy, griptape
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.16
#     Uninstalling urllib3-1.26.16:
#       Successfully uninstalled urllib3-1.26.16
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.9.3
#     Uninstalling lxml-4.9.3:
#       Successfully uninstalled lxml-4.9.3
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.2
#     Uninstalling Jinja2-3.1.2:
#       Successfully uninstalled Jinja2-3.1.2
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 2.0.4
#     Uninstalling charset-normalizer-2.0.4:
#       Successfully uninstalled charset-normalizer-2.0.4
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.29.76
#     Uninstalling botocore-1.29.76:
#       Successfully uninstalled botocore-1.29.76
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.4.3 requires pyqt5<5.16, which is not installed.
# spyder 5.4.3 requires pyqtwebengine<5.16, which is not installed.
# conda-repo-cli 1.0.75 requires requests_mock, which is not installed.
# aiobotocore 2.5.0 requires botocore<1.29.77,>=1.29.76, but you have botocore 1.34.54 which is incompatible.
# conda-repo-cli 1.0.75 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.75 requires PyYAML==6.0.1, but you have pyyaml 6.0 which is incompatible.
# Successfully installed anthropic-0.7.8 asn1crypto-1.5.1 backoff-2.2.1 boto3-1.34.54 boto3-stubs-1.34.54 botocore-1.34.54 botocore-stubs-1.34.54 charset-normalizer-3.3.2 cohere-4.51 contextlib2-21.6.0 courlan-1.0.0 dateparser-1.2.0 dnspython-2.6.1 docker-6.1.3 fastavro-1.9.4 griptape-0.23.0 htmldate-1.7.0 jinja2-3.1.3 justext-3.0.0 langcodes-3.3.0 loguru-0.7.2 lxml-5.1.0 mail-parser-3.15.0 marqo-3.1.0 marshmallow-3.21.0 marshmallow-enum-1.5.1 mypy-boto3-bedrock-1.34.0 mypy-boto3-iam-1.34.8 mypy-boto3-opensearch-1.34.43 mypy-boto3-s3-1.34.14 mypy-boto3-sagemaker-1.34.53 opensearch-py-2.4.2 pandas-1.5.3 pgvector-0.2.5 pillow-10.2.0 pinecone-client-2.2.4 psycopg2-binary-2.9.9 pymongo-4.6.2 pypdf-3.17.4 redis-4.6.0 rich-13.7.1 s3transfer-0.10.0 schema-0.7.5 simplejson-3.19.2 snowflake-connector-python-3.7.1 snowflake-sqlalchemy-1.5.1 sqlalchemy-redshift-0.8.14 stringcase-1.2.0 tld-0.13 trafilatura-1.7.0 types-awscrt-0.20.5 types-s3transfer-0.10.0 tzlocal-5.2 urllib3-1.26.18

# %%
from flask import Flask, request
from griptape.structures import Agent
from griptape.tools import WebScraper, FileManager, TaskMemoryClient
from randomNumberGenerator.tool import RandomNumberGenerator

# %%
# %env OPENAI_API_KEY=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
# Out:
# env: OPENAI_API_KEY=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

# %%
rng_tool = RandomNumberGenerator()
task_memory_client = TaskMemoryClient(off_prompt=True)
agent = Agent(
    tools=[rng_tool, FileManager(), ],
)
agent.run("generate a random number roundd to 5 decimal places and store it in a file rng.txt")
# Out:
# [03/03/24 07:46:04] INFO     ToolkitTask f30bb412462847f5baae9baef53223a6
#                              Input: generate a random number roundd to 5 decimal places and store it in a file
#                              rng.txt
# [03/03/24 07:46:10] INFO     Subtask a5f79a591a664aafb43b28f15bc6d8da
#                              Thought: First, I need to generate a random number rounded to 5 decimal places. I will
#                              use the RandomNumberGenerator action for this.
#
#                              Action:
#                              {
#                                "name": "RandomNumberGenerator",
#                                "path": "generate",
#                                "input": {
#                                  "values": {
#                                    "decimals": 5
#                                  }
#                                }
#                              }
#                     INFO     Subtask a5f79a591a664aafb43b28f15bc6d8da
#                              Response: Output of "RandomNumberGenerator.generate" was stored in memory with
#                              memory_name "TaskMemory" and artifact_namespace "c553d14ff2ea48d1b406a2f3b0dda8fc"
# [03/03/24 07:46:15] INFO     Subtask 3ad77a3104fc412bb728ccfcad3fc1ed
#                              Thought: Now that the random number is generated and stored in memory, I need to save
#                              it to a file named rng.txt. I will use the FileManager action for this, specifically
#                              the save_memory_artifacts_to_disk path.
#                              Action: {"name": "FileManager", "path": "save_memory_artifacts_to_disk", "input":
#                              {"values": {"dir_name": ".", "file_name": "rng.txt", "memory_name": "TaskMemory",
#                              "artifact_namespace": "c553d14ff2ea48d1b406a2f3b0dda8fc"}}}
#                     INFO     Subtask 3ad77a3104fc412bb728ccfcad3fc1ed
#                              Response: saved successfully
# [03/03/24 07:46:17] INFO     ToolkitTask f30bb412462847f5baae9baef53223a6
#                              Output: The random number has been successfully generated and stored in the file
#                              rng.txt.
# Agent(id='c743111b3bc44d968bcd8527c130c1fb', _stream=None, _prompt_driver=None, _embedding_driver=None, config=OpenAiStructureConfig(type='OpenAiStructureConfig', global_drivers=StructureGlobalDriversConfig(type='StructureGlobalDriversConfig', prompt_driver=OpenAiChatPromptDriver(min_retry_delay=2, max_retry_delay=10, max_attempts=10, after_hook=<function ExponentialBackoffMixin.<lambda> at 0x7f2fb910c400>, type='OpenAiChatPromptDriver', temperature=0.1, max_tokens=None, structure=..., prompt_stack_to_string=<bound method BasePromptDriver.default_prompt_stack_to_string_converter of ...>, stream=False, base_url=None, api_key=None, organization=None, client=<openai.OpenAI object at 0x7f2f97659290>, model='gpt-4', tokenizer=OpenAiTokenizer(stop_sequences=['<|Response|>'], model='gpt-4', max_tokens=8184), user='', response_format=None, seed=None, ignored_exception_types=(<class 'openai.BadRequestError'>, <class 'openai.AuthenticationError'>, <class 'openai.PermissionDeniedError'>, <class 'openai.NotFoundError'>, <class 'openai.ConflictError'>, <class 'openai.UnprocessableEntityError'>), _ratelimit_request_limit='5000', _ratelimit_requests_remaining='4999', _ratelimit_requests_reset_at=datetime.datetime(2024, 3, 3, 7, 46, 18, 537927), _ratelimit_token_limit='80000', _ratelimit_tokens_remaining='78622', _ratelimit_tokens_reset_at=datetime.datetime(2024, 3, 3, 7, 46, 18, 586966)), image_generation_driver=OpenAiImageGenerationDriver(min_retry_delay=2, max_retry_delay=10, max_attempts=10, after_hook=<function ExponentialBackoffMixin.<lambda> at 0x7f2fb910c400>, ignored_exception_types=(), type='OpenAiImageGenerationDriver', model='dall-e-2', structure=None, api_type=None, api_version=None, base_url=None, api_key=None, organization=None, client=<openai.OpenAI object at 0x7f2f9761f110>, style=None, quality='standard', image_size='512x512', response_format='b64_json'), image_query_driver=OpenAiVisionImageQueryDriver(min_retry_delay=2, max_retry_delay=10, max_attempts=10, after_hook=<function ExponentialBackoffMixin.<lambda> at 0x7f2fb910c400>, ignored_exception_types=(), type='OpenAiVisionImageQueryDriver', structure=None, model='gpt-4-vision-preview', api_type=None, api_version=None, base_url=None, api_key=None, organization=None, image_quality='auto', max_tokens=300, client=<openai.OpenAI object at 0x7f2f97603c90>), embedding_driver=OpenAiEmbeddingDriver(min_retry_delay=2, max_retry_delay=10, max_attempts=10, after_hook=<function ExponentialBackoffMixin.<lambda> at 0x7f2fb910c400>, ignored_exception_types=(), type='OpenAiEmbeddingDriver', chunker=TextChunker(separators=[ChunkSeparator(value='\n\n', is_prefix=False), ChunkSeparator(value='\n', is_prefix=False), ChunkSeparator(value='. ', is_prefix=False), ChunkSeparator(value='! ', is_prefix=False), ChunkSeparator(value='? ', is_prefix=False), ChunkSeparator(value=' ', is_prefix=False)], tokenizer=OpenAiTokenizer(stop_sequences=['<|Response|>'], model='text-embedding-ada-002', max_tokens=8191), max_tokens=8191), model='text-embedding-ada-002', base_url=None, api_key=None, organization=None, client=<openai.OpenAI object at 0x7f2f97c41b10>, tokenizer=OpenAiTokenizer(stop_sequences=['<|Response|>'], model='text-embedding-ada-002', max_tokens=8191)), vector_store_driver=LocalVectorStoreDriver(type='LocalVectorStoreDriver', embedding_driver=OpenAiEmbeddingDriver(min_retry_delay=2, max_retry_delay=10, max_attempts=10, after_hook=<function ExponentialBackoffMixin.<lambda> at 0x7f2fb910c400>, ignored_exception_types=(), type='OpenAiEmbeddingDriver', chunker=TextChunker(separators=[ChunkSeparator(value='\n\n', is_prefix=False), ChunkSeparator(value='\n', is_prefix=False), ChunkSeparator(value='. ', is_prefix=False), ChunkSeparator(value='! ', is_prefix=False), ChunkSeparator(value='? ', is_prefix=False), ChunkSeparator(value=' ', is_prefix=False)], tokenizer=OpenAiTokenizer(stop_sequences=['<|Response|>'], model='text-embedding-ada-002', max_tokens=8191), max_tokens=8191), model='text-embedding-a ...

# %%
dir(agent)
# Out:
# ['LOGGER_NAME',
#  '__abstractmethods__',
#  '__add__',
#  '__annotations__',
#  '__attrs_attrs__',
#  '__attrs_own_setattr__',
#  '__attrs_post_init__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__match_args__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_embedding_driver',
#  '_execution_args',
#  '_logger',
#  '_prompt_driver',
#  '_stream',
#  'add_event_listener',
#  'add_task',
#  'add_tasks',
#  'after_run',
#  'before_run',
#  'config',
#  'context',
#  'conversation_memory',
#  'custom_logger',
#  'default_config',
#  'default_task_memory',
#  'embedding_driver',
#  'event_listeners',
#  'execution_args',
#  'find_task',
#  'finished_tasks',
#  'id',
#  'input_task',
#  'input_template',
#  'is_executing',
#  'is_finished',
#  'logger',
#  'logger_level',
#  'max_meta_memory_entries',
#  'meta_memory',
#  'output_task',
#  'prompt_driver',
#  'publish_event',
#  'remove_event_listener',
#  'rules',
#  'rulesets',
#  'run',
#  'stream',
#  'task',
#  'task_memory',
#  'tasks',
#  'tools',
#  'try_run',
#  'validate_rules',
#  'validate_rulesets']

# %%
dir(agent.task_memory.artifact_storages)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
agent.task_memory.artifact_storages.get(
# Out:
# dict_items([(<class 'griptape.artifacts.text_artifact.TextArtifact'>, TextArtifactStorage(query_engine=VectorQueryEngine(answer_token_offset=400, vector_store_driver=LocalVectorStoreDriver(type='LocalVectorStoreDriver', embedding_driver=OpenAiEmbeddingDriver(min_retry_delay=2, max_retry_delay=10, max_attempts=10, after_hook=<function ExponentialBackoffMixin.<lambda> at 0x7f2fb910c400>, ignored_exception_types=(), type='OpenAiEmbeddingDriver', chunker=TextChunker(separators=[ChunkSeparator(value='\n\n', is_prefix=False), ChunkSeparator(value='\n', is_prefix=False), ChunkSeparator(value='. ', is_prefix=False), ChunkSeparator(value='! ', is_prefix=False), ChunkSeparator(value='? ', is_prefix=False), ChunkSeparator(value=' ', is_prefix=False)], tokenizer=OpenAiTokenizer(stop_sequences=['<|Response|>'], model='text-embedding-ada-002', max_tokens=8191), max_tokens=8191), model='text-embedding-ada-002', base_url=None, api_key=None, organization=None, client=<openai.OpenAI object at 0x7f2f97601350>, tokenizer=OpenAiTokenizer(stop_sequences=['<|Response|>'], model='text-embedding-ada-002', max_tokens=8191)), futures_executor=<concurrent.futures.thread.ThreadPoolExecutor object at 0x7f2f9762b690>, entries={'c553d14ff2ea48d1b406a2f3b0dda8fc-c553d14ff2ea48d1b406a2f3b0dda8fc': BaseVectorStoreDriver.Entry(id='c553d14ff2ea48d1b406a2f3b0dda8fc', vector=[0.02722885273396969, -0.004061275627464056, 0.00846833549439907, -0.024381212890148163, -0.013343222439289093, 0.026862727478146553, -0.023459119722247124, -0.0017492639599367976, -0.03314109146595001, -0.01460431981831789, -0.008447995409369469, 0.0299137681722641, -0.004790135659277439, 0.006773312576115131, -0.007810666691511869, 0.006919084582477808, 0.004688434302806854, -0.007268259301781654, 0.006132593844085932, -0.029642565175890923, -0.02589995414018631, 0.013411023654043674, -0.011926183477044106, 0.0015416236128658056, -0.026754245162010193, -0.0053088124841451645, 0.003942623734474182, -0.009478569962084293, 0.004708774387836456, -0.03387334197759628, 0.018238449469208717, -0.011858382262289524, -0.039568621665239334, -0.03281565010547638, -0.009295507334172726, -0.00031781685538589954, -0.006668221205472946, -0.009607391431927681, 0.029886648058891296, 0.002225565491244197, -0.0011458356166258454, 0.014428037218749523, 0.00609191320836544, 0.007675064727663994, -0.01951310597360134, 0.01971650868654251, 0.007573363371193409, -0.01990635134279728, -0.01806216686964035, 0.01795368455350399, 0.0060105519369244576, -0.003091722261160612, -0.015946777537465096, -0.010197259485721588, 0.008915822021663189, 0.003020531265065074, -0.012902515940368176, 0.005942751187831163, 0.007803886663168669, -0.014333115890622139, -0.018604574725031853, -0.02145221270620823, -0.027676338329911232, 0.004912177100777626, -0.008556476794183254, -0.001660275156609714, -0.012888955883681774, 0.00415280694141984, 0.009898935444653034, 0.017587561160326004, 0.007064856588840485, 0.029805287718772888, 0.01868593506515026, -0.032544445246458054, 0.035256482660770416, 0.004237557761371136, -0.031839314848184586, 0.01587897725403309, -0.002618810860440135, 0.006312266457825899, 0.011790581047534943, -0.022835351526737213, -0.018821537494659424, -0.004820645786821842, 0.018509652465581894, -0.030673138797283173, -0.0035934490151703358, 0.014048351906239986, -0.01217704638838768, -0.0036578599829226732, 0.0273373331874609, -0.0025306695606559515, 0.003552768612280488, -0.012719454243779182, -8.771744614932686e-05, -0.022414986044168472, -0.022753991186618805, 0.048436980694532394, 0.010821027681231499, -0.016651907935738564, -0.01796724647283554, -0.008007289841771126, -0.014536518603563309, -0.01765536144375801, -0.009553150273859501, -0.007329280022531748, 0.012536391615867615, -0.016679028049111366, -0.013851729221642017, -0.009003963321447372, -0.018238449469208717, 0.025059223175048828, -0.00907176360487938, -0.017682481557130814, 0.034198787063360214, -0.011126131750643253, 0.00649871863424778, 0.0123058678 ...
